# %% [markdown]
# Using the data generated by KatoData.ipynb, I think it is important to start implementing the relevant clustering algorithms.
#
# Here are my thoughts on the matter:
#
# 1. Markov Cluster Algorithm: http://micans.org/mcl/
# 2. Functional Clustering Algorithm: see Sarah Feldt paper for details
# 3. Computation Characterization with fourier transforms in dynamical networks
# 4. Novel algorithm for clustering both with functional and connectome data.
#
# Viz implementing MCA, I think this will be a good opportunity to learn some Cython.
#
# Viz FCA, we can implement this in pure python/numpy.
#
# *4/19/16*
# In KatoData we implemented agglomerative clustering - that should be ported here as soon as possible.
#
# Some additional approaches we should think about:
#
# 1. Dynamics/Clustering gradients in the high-dimensional parameter space
# 2. Identification of minimal network: feedforward and feedbackward theory using multilayered networks.
# 3. Trying to identify role of **peripheral neurons** by comparing pruned vs included simulations
# 3. Other networks structures and parameters using the same simulator – do theories hold true for them.
# 4. **Theory for how correlations are created in a network**
# 5. Random sampling – developing a model to infer connectivity structures from functional data. What kinds of features do different connectivities create and can analagous dynamics arise from disparate connectivities? Linear/Nonlinear affects of peripheral neurons as well as combination of different sets of peripheral neurons.
# 6. Do our results change with over a sliding window on the datasets, i.e. splitting them into smaller datasets. What are the minimal conditions to get these results?
# 7. Statistics/ML
#     - Markov matrices
#     - Probability distributions over sliding window

# %%
import numpy as np
import random

import matplotlib.pyplot as plt

import sys

#Add the src folder to the sys.path list
sys.path.append('../src/')
import data_config as dc

import networkx as nx
# Out:
# Reading

# %%
connectome = dc.connectome_networkx.data()
# Out:
# Generating
# Reading

# %% [markdown]
# I'd like to see if we can identify a minimal network for C Elegans. Perhaps we can demonstrate that periphal neurons to the minimal network can add precision/nuance to the movement of the worm, but that the general dynamics can be approximated by a minimal network.
#
# It would be interesting to see if a theory of a minimal network is in fact supportable. This would enable us to show exactly what individual local processing units/peripheral functional pathways contribute.
#
# I'm not going to shave yaks, but there's a lot

# %% [markdown]
# Now that we've assembled a machine-readable connectome, I'd like to trace all forward facing pathways in the network.

# %%
not_visited = sensory_neurons
visited = {}
nodes = network.nodes()

while not_visited:
    node = nodes.pop(0)
    edges = network.edge(node)
    for s,e in edges:
        if not e in visited: 
            not_visited.append(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7e47aff4c389> in <module>()
# ----> 1 not_visited = sensory_neurons
#       2 visited = {}
#       3 nodes = network.nodes()
#       4
#       5 while not_visited:
#
# NameError: name 'sensory_neurons' is not defined
