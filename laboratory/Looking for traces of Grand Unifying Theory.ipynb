# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import numpy as np
import scipy.cluster.hierarchy as sch
import pylab
import scipy
import matplotlib.pyplot as plt
import networkx as nx
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../src/')
import data_config  as dc
katodata = dc.kato.data()
series = katodata[0]['deltaFOverF']
series = series[:107,:107]

# %%
G = nx.from_numpy_matrix(series)
nx.draw_graphviz(G)

# %%
for i,data in katodata.iteritems():
    delta = data['deltaFOverF_deriv']
    calcium = data['deltaFOverF_bc']
    plt.figure()
    plt.pcolormesh(delta)
    plt.figure()
    plt.pcolormesh(calcium)

# %% [markdown]
# - Which neurons do these traces come from and if they are not the same, why are there correlations?
# - We need to understand what prompted this wave to travel through the network. Is it in the same neurons? Can we crosscorrelate with sensory input?
#
# The grand theory would predict everything that is happening because it unifies the various major theories of neurocience. It would predict temporally global and local changes.
